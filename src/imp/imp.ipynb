# %%
import IMP
import IMP.core
import IMP.algebra
import IMP.atom
import IMP.container

import IMP.pmi.restraints.crosslinking
import IMP.pmi.restraints.stereochemistry
import IMP.pmi.restraints.em
import IMP.pmi.restraints.basic
import IMP.pmi.tools
import IMP.pmi.samplers
import IMP.pmi.output
import IMP.pmi.macros
import IMP.pmi.topology

# %%
distancemax = 10
distancemin = 0
kappa = 1.0

# %%
ts1 = IMP.core.HarmonicUpperBound(distancemax, kappa)
ts2 = IMP.core.HarmonicLowerBound(distancemin, kappa)

# %%
help(ts1)
# Out:
# Help on HarmonicUpperBound in module IMP.core object:
#
# class HarmonicUpperBound(Harmonic)
#  |  HarmonicUpperBound(mean, k)
#  |
#  |  Proxy of C++ IMP::core::HarmonicUpperBound class.
#  |
#  |  Method resolution order:
#  |      HarmonicUpperBound
#  |      Harmonic
#  |      IMP.UnaryFunction
#  |      IMP.Object
#  |      IMP._NonCopyable
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, mean, k)
#  |      __init__(HarmonicUpperBound self, IMP::Float mean, IMP::Float k) -> HarmonicUpperBound
#  |
#  |  __repr__(self)
#  |      __repr__(HarmonicUpperBound self) -> std::string
#  |
#  |  __str__(self)
#  |      __str__(HarmonicUpperBound self) -> std::string
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  get_from(o)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  thisown
#  |      The membership flag
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from Harmonic:
#  |
#  |  get_k(self)
#  |      get_k(Harmonic self) -> IMP::Float
#  |
#  |  get_mean(self)
#  |      get_mean(Harmonic self) -> IMP::Float
#  |
#  |  get_version_info(self)
#  |      get_version_info(Harmonic self) -> VersionInfo
#  |
#  |  set_k(self, k)
#  |      set_k(Harmonic self, IMP::Float k)
#  |
#  |  set_mean(self, mean)
#  |      set_mean(Harmonic self, IMP::Float mean)
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods inherited from Harmonic:
#  |
#  |  get_k_from_standard_deviation(sd, t=297.15)
#  |      get_k_from_standard_deviation(IMP::Float sd, IMP::Float t=297.15) -> IMP::Float
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from IMP.UnaryFunction:
#  |
#  |  __disown__(self)
#  |
#  |  do_destroy(self)
#  |      do_destroy(UnaryFunction self)
#  |
#  |  do_show(self, out)
#  |
#  |  evaluate(self, feature)
#  |      evaluate(UnaryFunction self, double feature) -> double
#  |
#  |  evaluate_with_derivative(self, feature)
#  |      evaluate_with_derivative(UnaryFunction self, double feature) -> IMP::DerivativePair
#  |
#  |  get_type_name(self)
#  |      get_type_name(Object self) -> std::string
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods inherited from IMP.UnaryFunction:
#  |
#  |  __swig_destroy__ = delete_UnaryFunction(...)
#  |      delete_UnaryFunction(UnaryFunction self)
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from IMP.Object:
#  |
#  |  __eq__(self, o)
#  |      __eq__(Object self, Object o) -> bool
#  |
#  |  __ge__(self, o)
#  |      __ge__(Object self, Object o) -> bool
#  |
#  |  __gt__(self, o)
#  |      __gt__(Object self, Object o) -> bool
#  |
#  |  __hash__(self)
#  |      __hash__(Object self) -> std::size_t
#  |
#  |  __le__(self, o)
#  |      __le__(Object self, Object o) -> bool
#  |
#  |  __lt__(self, o)
#  |      __lt__(Object self, Object o) -> bool
#  |
#  |  __ne__(self, o)
#  |      __ne__(Object self, Object o) -> bool
#  |
#  |  clear_caches(self)
#  |      clear_caches(Object self)
#  |
#  |  get_check_level(self)
#  |      get_check_level(Object self) -> IMP::CheckLevel
#  |
#  |  get_is_shared(self)
#  |      get_is_shared(Object self) -> bool
#  |
#  |  get_is_valid(self)
#  |      get_is_valid(Object self) -> bool
#  |
#  |  get_log_level(self)
#  |      get_log_level(Object self) -> IMP::LogLevel
#  |
#  |  get_name(self)
#  |      get_name(Object self) -> std::string const &
#  |
#  |  get_ref_count(self)
#  |      get_ref_count(Object self) -> unsigned int
#  |
#  |  get_string(self)
#  |      get_string(Object self) -> std::string
#  |
#  |  set_check_level(self, l)
#  |      set_check_level(Object self, IMP::CheckLevel l)
#  |
#  |  set_log_level(self, l)
#  |      set_log_level(Object self, IMP::LogLevel l)
#  |
#  |  set_name(self, name)
#  |      set_name(Object self, std::string name)
#  |
#  |  set_was_used(self, tf)
#  |      set_was_used(Object self, bool tf)
#  |
#  |  show(self, *args)
#  |      show(Object self, _ostream out=std::cout)
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods inherited from IMP.Object:
#  |
#  |  get_number_of_live_objects()
#  |      get_number_of_live_objects() -> unsigned int
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from IMP._NonCopyable:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
